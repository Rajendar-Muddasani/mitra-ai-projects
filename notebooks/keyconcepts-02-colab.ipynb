# %% [markdown]
# # Google Colab
# Free cloud notebooks with GPU access and Google Drive integration.

# %%
import micropip
await micropip.install(['numpy'])
print('Ready!')

# %% [markdown]
# ## Colab vs Kaggle
#
# | | Colab Free | Kaggle Free | Colab Pro |
# |---|---|---|---|
# | GPU | T4 (limited) | T4 30hr/wk | A100/V100 |
# | RAM | 12GB | 29GB | 52GB |
# | Session | 12 hours | 9 hours | 24 hours |

# %%
colab_patterns = {
    "Mount Drive": "from google.colab import drive; drive.mount('/content/drive')",
    "Install packages": "!pip install -q transformers datasets",
    "Download data": "!wget -q https://example.com/data.zip && unzip -q data.zip",
    "Save to Drive": "import shutil; shutil.copy('model.pkl', '/content/drive/MyDrive/')",
    "Check GPU": "!nvidia-smi  # shows GPU info",
}
print("Common Colab patterns:")
for pattern, code in colab_patterns.items():
    print(f"  {pattern}: {code[:60]}...")

# %% [markdown]
# ---
# **Your turn:** Open colab.research.google.com, mount Drive, run `!nvidia-smi`. What GPU do you have?
